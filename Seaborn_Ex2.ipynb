# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('Pokemon.csv',index_col=0,encoding='unicode_escape')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 1 to 721
# Data columns (total 12 columns):
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# Total         800 non-null int64
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 75.8+ KB

# %%
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
#2.1 scatterplot: sb.swarmplot (phan loai voi cac diem khong chong cheo)
plt.figure(figsize=(8,6))
sb.swarmplot(data=df, x='Attack',y='Defense')
plt.show()

# %%
#2.2 scatterplot: sb.jointplot 
plt.figure(figsize=(8,6))
sb.set()
sb.jointplot(data=df, x='Attack',y='Defense',kind='reg',color='orange')
plt.show()

# %%
#Ex2.3 #regression plot x='	Attack', y='Speed' #regplot
sb.regplot(data=df,x='Attack', y='Speed' )
plt.show()

# %%
#Ex2.4 boxplot cho toan bo du lieu
sb.boxplot(data=df, x='Total')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sb
plt.figure(figsize=(16,12))
sb.boxplot(data=df, x='Type 1',y='HP')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sb
plt.figure(figsize=(16,12))
sb.boxplot(data=df, x='Type 2',y='Attack')
plt.show()

# %%
plt.figure(figsize=(16,12))
sb.boxplot(data=df, x='Generation',y='Speed')
plt.show()

# %%
plt.figure(figsize=(16,12))
sb.boxplot(data=df, x='Generation',y='Attack',hue='Type 2')
plt.show()

# %%
#Ex2.6 histogram: sb.distplot()
sb.distplot(df['Attack'],kde=False)
plt.show()

# %%
#Ex2.7 sb.barplot()
df['Type 1']
# Out:
# #
# 1        Grass
# 2        Grass
# 3        Grass
# 3        Grass
# 4         Fire
#         ...
# 719       Rock
# 719       Rock
# 720    Psychic
# 720    Psychic
# 721       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
type1=df.groupby('Type 1').count()
type1['Type1']=type1.index
type1
# Out:
#           Name  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug         69      52     69   69      69       69       69       69     69
# Dark        31      21     31   31      31       31       31       31     31
# Dragon      32      21     32   32      32       32       32       32     32
# Electric    44      17     44   44      44       44       44       44     44
# Fairy       17       2     17   17      17       17       17       17     17
# Fighting    27       7     27   27      27       27       27       27     27
# Fire        52      24     52   52      52       52       52       52     52
# Flying       4       2      4    4       4        4        4        4      4
# Ghost       32      22     32   32      32       32       32       32     32
# Grass       70      37     70   70      70       70       70       70     70
# Ground      32      19     32   32      32       32       32       32     32
# ...

# %%
plt.figure(figsize=(16,12))
sb.barplot(data=type1, x='Type1', y='Name',order=None)
plt.show()
